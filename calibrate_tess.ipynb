# %%
import pandas as pd
from astropy.time import Time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from astropy.io import fits
from astropy.table import Table
from glob import glob
from scipy.signal import savgol_filter

import pysynphot as S
from extinction import fm07, fitzpatrick99, apply

def my_norm(Spec,pbs,mag):
    from copy import deepcopy
    spec = deepcopy(Spec)
    #m = Syn_mag(pbs,spec)
    syn_mag = source_synphot.passband.synphot(spec,pbs['ps1r'][0],zp=pbs['ps1r'][1])
    m = syn_mag
    factor = 10**(-2/5*(mag-m))
    print(factor)
    spec = S.ArraySpectrum(wave=spec.wave,waveunits=spec.waveunits,
                                   flux=spec.flux*factor,fluxunits=spec.fluxunits)
    return spec

# %%
specs = glob('spec/*.flm')
s1 = np.loadtxt(specs[0])
s2 = np.loadtxt(specs[1])

# %%
plt.figure()
plt.plot(s1[:,0],s1[:,1])
plt.plot(s2[:,0],s2[:,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s1.shape
# Out:
# (1435, 2)
